# %%
# Librerías estándar y de terceros
import os
import sys
import gc
import math as m
import numpy as np
import scipy
import pandas as pd
from scipy import *
from scipy.signal import butter, filtfilt, hilbert
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# Configuración de rutas para importaciones personalizadas
sys.path.append('/projects/DEIKE/cmartinb/jupyter_notebook/project_specific/turbulence')
sys.path.append('/projects/DEIKE/cmartinb/functions')
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Funciones y clases personalizadas
from prepare import load_object, save_object, field
from defs import Case, Interface2D
from phase import extract_phase
from funciones import *  # Asegúrate de que la importación con * sea necesaria, a veces es mejor importar solo las funciones necesarias

os.chdir('/projects/DEIKE/cmartinb/')

# %%
def read_surface(filename, N):
    val = np.fromfile(filename, dtype=np.float32)
    val = val.reshape(N,N)
    return val

# %%
# DEFINE CASE SO WE CAN AUTHOMATIZE IT 
kpHs = '0p16' # 0p16 
uoc = '0p50' # 0p50 0p75
reW = '2.5e4' #1.0e5
reA = 720
#maxLevel = 10
maxLevel = 10
Bo=1000 # 25, 1000

rho1=1
rho2=1*10**(-3)

if reW == '1.0e5':
    Re_water = 1 * 10**5
else:
    Re_water = 2.5 * 10**4

if maxLevel == 11:
    N = 1024
else:
    N = 512 

#Common parameters 
kp = 4
u = 0.25
lambdap = 2*m.pi/kp

L0 = 2*np.pi;

ak,  c, omegap, nu_water, g, uoc_val, sigma, Tp= calculate_parameters(kpHs, uoc, u, kp, Bo, rho1, rho2)
print('ak is', ak, 'c is' ,c, 'w_p$ is', omegap, '$\nu_w$ is' , nu_water, 'g is' ,g, 'N', N)
# Out:
# ak is 0.16 c is 0.5 w_p$ is 2.0 $
# u_w$ is 3.141592653589793e-05 g is 0.999001997004992 N 512

# %%
def read_surface(filename, N):
    val = np.fromfile(filename, dtype=np.float32)
    val = val.reshape(N,N)
    return val

# %%
#work_dir = f'/projects/DEIKE/nscapin/broadband_reorder/re{reA}_bo0{Bo}_P{kpHs}_uoc{uoc}_reW{reW}_L{maxLevel}/'
#for Bo=1000 I run the simulation
#work_dir = f'/projects/DEIKE/cmartinb/cases_multiphase_broadbanded/re{reA}_bo{Bo}_kpHs{kpHs}_uoc{uoc}_reW{reW}_L{maxLevel}/'
work_dir = '/projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/'
#data = np.loadtxt(work_dir+'eta/global_int.out')
#re720_bo0200_P0p16_uoc0p50_reW1.0e5_L10
#istep_c =data[:, 1]
#time = data[:,0] 
#print(istep_c)
#print(time.shape)

# %%
val = read_surface(work_dir + '/eta_matrix_000000000', N)
print(val.shape)
# Out:
# (1024, 1024)

# %%
import re 
N = 1024

eta_series = np.zeros((istep_c.shape[0],N,N), dtype=np.float32)
j=0
#val = read_surface(work_dir + '/eta_matrix_000000000', N)

pattern = re.compile(r'eta_matrix_(\d+)$')
files = []
for fname in os.listdir(work_dir):
    m = pattern.match(fname)
    if m:
        files.append((int(m.group(1)), fname))
# Ordeno por el número de iteración (el grupo (\d+))
files.sort(key=lambda x: x[0])


# --- Reservo el array 3D para almacenar la serie ---
n_steps = len(files)
eta_series = np.empty((n_steps, N, N), dtype= np.float32  )

# --- Bucle de lectura ---
for idx, (_, fname) in enumerate(files):
    fullpath = os.path.join(work_dir, fname)
    # Si es binario:
    print(fullpath)
    data = read_surface(fullpath,N)
    eta_series[idx, :, :] = data
    print(f'Leído step {idx:03d} ← {fname}')
# Out:
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000000
# Leído step 000 ← eta_matrix_000000000
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000021
# Leído step 001 ← eta_matrix_000000021
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000049
# Leído step 002 ← eta_matrix_000000049
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000084
# Leído step 003 ← eta_matrix_000000084
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000121
# Leído step 004 ← eta_matrix_000000121
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000157
# Leído step 005 ← eta_matrix_000000157
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000193
# Leído step 006 ← eta_matrix_000000193
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000229
# Leído step 007 ← eta_matrix_000000229
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000263
# Leído step 008 ← eta_matrix_000000263
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000294
# Leído step 009 ← eta_matrix_000000294
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000324
# Leído step 010 ← eta_matrix_000000324
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000355
# Leído step 011 ← eta_matrix_000000355
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000387
# Leído step 012 ← eta_matrix_000000387
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000420
# Leído step 013 ← eta_matrix_000000420
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000454
# Leído step 014 ← eta_matrix_000000454
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000488
# Leído step 015 ← eta_matrix_000000488
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000522
# Leído step 016 ← eta_matrix_000000522
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000558
# Leído step 017 ← eta_matrix_000000558
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000595
# Leído step 018 ← eta_matrix_000000595
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000631
# Leído step 019 ← eta_matrix_000000631
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000667
# Leído step 020 ← eta_matrix_000000667
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000703
# Leído step 021 ← eta_matrix_000000703
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000739
# Leído step 022 ← eta_matrix_000000739
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000774
# Leído step 023 ← eta_matrix_000000774
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000809
# Leído step 024 ← eta_matrix_000000809
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000843
# Leído step 025 ← eta_matrix_000000843
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000878
# Leído step 026 ← eta_matrix_000000878
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000914
# Leído step 027 ← eta_matrix_000000914
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000949
# Leído step 028 ← eta_matrix_000000949
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000000984
# Leído step 029 ← eta_matrix_000000984
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001020
# Leído step 030 ← eta_matrix_000001020
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001056
# Leído step 031 ← eta_matrix_000001056
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001093
# Leído step 032 ← eta_matrix_000001093
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001131
# Leído step 033 ← eta_matrix_000001131
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001169
# Leído step 034 ← eta_matrix_000001169
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001206
# Leído step 035 ← eta_matrix_000001206
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001242
# Leído step 036 ← eta_matrix_000001242
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001277
# Leído step 037 ← eta_matrix_000001277
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001312
# Leído step 038 ← eta_matrix_000001312
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001347
# Leído step 039 ← eta_matrix_000001347
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001380
# Leído step 040 ← eta_matrix_000001380
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001412
# Leído step 041 ← eta_matrix_000001412
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001443
# Leído step 042 ← eta_matrix_000001443
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001475
# Leído step 043 ← eta_matrix_000001475
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001507
# Leído step 044 ← eta_matrix_000001507
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001540
# Leído step 045 ← eta_matrix_000001540
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001574
# Leído step 046 ← eta_matrix_000001574
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001609
# Leído step 047 ← eta_matrix_000001609
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001645
# Leído step 048 ← eta_matrix_000001645
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001680
# Leído step 049 ← eta_matrix_000001680
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001714
# Leído step 050 ← eta_matrix_000001714
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001747
# Leído step 051 ← eta_matrix_000001747
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001780
# Leído step 052 ← eta_matrix_000001780
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001813
# Leído step 053 ← eta_matrix_000001813
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001848
# Leído step 054 ← eta_matrix_000001848
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001884
# Leído step 055 ← eta_matrix_000001884
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001920
# Leído step 056 ← eta_matrix_000001920
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001956
# Leído step 057 ← eta_matrix_000001956
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000001991
# Leído step 058 ← eta_matrix_000001991
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002024
# Leído step 059 ← eta_matrix_000002024
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002055
# Leído step 060 ← eta_matrix_000002055
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002084
# Leído step 061 ← eta_matrix_000002084
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002113
# Leído step 062 ← eta_matrix_000002113
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002142
# Leído step 063 ← eta_matrix_000002142
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002172
# Leído step 064 ← eta_matrix_000002172
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002203
# Leído step 065 ← eta_matrix_000002203
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002234
# Leído step 066 ← eta_matrix_000002234
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002265
# Leído step 067 ← eta_matrix_000002265
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002296
# Leído step 068 ← eta_matrix_000002296
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002326
# Leído step 069 ← eta_matrix_000002326
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002357
# Leído step 070 ← eta_matrix_000002357
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002388
# Leído step 071 ← eta_matrix_000002388
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002419
# Leído step 072 ← eta_matrix_000002419
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002450
# Leído step 073 ← eta_matrix_000002450
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002479
# Leído step 074 ← eta_matrix_000002479
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002508
# Leído step 075 ← eta_matrix_000002508
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002536
# Leído step 076 ← eta_matrix_000002536
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002564
# Leído step 077 ← eta_matrix_000002564
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002592
# Leído step 078 ← eta_matrix_000002592
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002621
# Leído step 079 ← eta_matrix_000002621
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002652
# Leído step 080 ← eta_matrix_000002652
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002682
# Leído step 081 ← eta_matrix_000002682
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002712
# Leído step 082 ← eta_matrix_000002712
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002742
# Leído step 083 ← eta_matrix_000002742
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002773
# Leído step 084 ← eta_matrix_000002773
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002804
# Leído step 085 ← eta_matrix_000002804
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002836
# Leído step 086 ← eta_matrix_000002836
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002871
# Leído step 087 ← eta_matrix_000002871
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002906
# Leído step 088 ← eta_matrix_000002906
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002942
# Leído step 089 ← eta_matrix_000002942
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000002978
# Leído step 090 ← eta_matrix_000002978
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003014
# Leído step 091 ← eta_matrix_000003014
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003049
# Leído step 092 ← eta_matrix_000003049
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003083
# Leído step 093 ← eta_matrix_000003083
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003119
# Leído step 094 ← eta_matrix_000003119
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003156
# Leído step 095 ← eta_matrix_000003156
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003192
# Leído step 096 ← eta_matrix_000003192
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003229
# Leído step 097 ← eta_matrix_000003229
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003268
# Leído step 098 ← eta_matrix_000003268
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003306
# Leído step 099 ← eta_matrix_000003306
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003345
# Leído step 100 ← eta_matrix_000003345
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003384
# Leído step 101 ← eta_matrix_000003384
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003422
# Leído step 102 ← eta_matrix_000003422
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003459
# Leído step 103 ← eta_matrix_000003459
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003496
# Leído step 104 ← eta_matrix_000003496
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003532
# Leído step 105 ← eta_matrix_000003532
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003567
# Leído step 106 ← eta_matrix_000003567
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003600
# Leído step 107 ← eta_matrix_000003600
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003633
# Leído step 108 ← eta_matrix_000003633
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003666
# Leído step 109 ← eta_matrix_000003666
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003699
# Leído step 110 ← eta_matrix_000003699
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003732
# Leído step 111 ← eta_matrix_000003732
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003766
# Leído step 112 ← eta_matrix_000003766
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003805
# Leído step 113 ← eta_matrix_000003805
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003844
# Leído step 114 ← eta_matrix_000003844
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003880
# Leído step 115 ← eta_matrix_000003880
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003917
# Leído step 116 ← eta_matrix_000003917
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003956
# Leído step 117 ← eta_matrix_000003956
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000003995
# Leído step 118 ← eta_matrix_000003995
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004033
# Leído step 119 ← eta_matrix_000004033
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004070
# Leído step 120 ← eta_matrix_000004070
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004107
# Leído step 121 ← eta_matrix_000004107
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004142
# Leído step 122 ← eta_matrix_000004142
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004175
# Leído step 123 ← eta_matrix_000004175
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004208
# Leído step 124 ← eta_matrix_000004208
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004241
# Leído step 125 ← eta_matrix_000004241
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004274
# Leído step 126 ← eta_matrix_000004274
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004309
# Leído step 127 ← eta_matrix_000004309
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004342
# Leído step 128 ← eta_matrix_000004342
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004374
# Leído step 129 ← eta_matrix_000004374
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004405
# Leído step 130 ← eta_matrix_000004405
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004435
# Leído step 131 ← eta_matrix_000004435
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004464
# Leído step 132 ← eta_matrix_000004464
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004493
# Leído step 133 ← eta_matrix_000004493
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004523
# Leído step 134 ← eta_matrix_000004523
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004555
# Leído step 135 ← eta_matrix_000004555
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004589
# Leído step 136 ← eta_matrix_000004589
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004627
# Leído step 137 ← eta_matrix_000004627
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004667
# Leído step 138 ← eta_matrix_000004667
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004707
# Leído step 139 ← eta_matrix_000004707
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004748
# Leído step 140 ← eta_matrix_000004748
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004789
# Leído step 141 ← eta_matrix_000004789
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004830
# Leído step 142 ← eta_matrix_000004830
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004868
# Leído step 143 ← eta_matrix_000004868
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004904
# Leído step 144 ← eta_matrix_000004904
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004939
# Leído step 145 ← eta_matrix_000004939
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000004973
# Leído step 146 ← eta_matrix_000004973
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005006
# Leído step 147 ← eta_matrix_000005006
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005038
# Leído step 148 ← eta_matrix_000005038
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005070
# Leído step 149 ← eta_matrix_000005070
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005102
# Leído step 150 ← eta_matrix_000005102
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005133
# Leído step 151 ← eta_matrix_000005133
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005164
# Leído step 152 ← eta_matrix_000005164
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005195
# Leído step 153 ← eta_matrix_000005195
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005225
# Leído step 154 ← eta_matrix_000005225
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005256
# Leído step 155 ← eta_matrix_000005256
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005287
# Leído step 156 ← eta_matrix_000005287
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005319
# Leído step 157 ← eta_matrix_000005319
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005351
# Leído step 158 ← eta_matrix_000005351
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005382
# Leído step 159 ← eta_matrix_000005382
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005413
# Leído step 160 ← eta_matrix_000005413
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005443
# Leído step 161 ← eta_matrix_000005443
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005475
# Leído step 162 ← eta_matrix_000005475
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005508
# Leído step 163 ← eta_matrix_000005508
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005544
# Leído step 164 ← eta_matrix_000005544
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005581
# Leído step 165 ← eta_matrix_000005581
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005618
# Leído step 166 ← eta_matrix_000005618
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005655
# Leído step 167 ← eta_matrix_000005655
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005691
# Leído step 168 ← eta_matrix_000005691
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005725
# Leído step 169 ← eta_matrix_000005725
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005757
# Leído step 170 ← eta_matrix_000005757
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005787
# Leído step 171 ← eta_matrix_000005787
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005817
# Leído step 172 ← eta_matrix_000005817
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005848
# Leído step 173 ← eta_matrix_000005848
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005881
# Leído step 174 ← eta_matrix_000005881
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005915
# Leído step 175 ← eta_matrix_000005915
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005949
# Leído step 176 ← eta_matrix_000005949
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000005982
# Leído step 177 ← eta_matrix_000005982
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006013
# Leído step 178 ← eta_matrix_000006013
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006045
# Leído step 179 ← eta_matrix_000006045
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006078
# Leído step 180 ← eta_matrix_000006078
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006111
# Leído step 181 ← eta_matrix_000006111
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006145
# Leído step 182 ← eta_matrix_000006145
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006178
# Leído step 183 ← eta_matrix_000006178
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006210
# Leído step 184 ← eta_matrix_000006210
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006240
# Leído step 185 ← eta_matrix_000006240
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006269
# Leído step 186 ← eta_matrix_000006269
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006297
# Leído step 187 ← eta_matrix_000006297
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006325
# Leído step 188 ← eta_matrix_000006325
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006352
# Leído step 189 ← eta_matrix_000006352
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006379
# Leído step 190 ← eta_matrix_000006379
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006407
# Leído step 191 ← eta_matrix_000006407
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006436
# Leído step 192 ← eta_matrix_000006436
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006464
# Leído step 193 ← eta_matrix_000006464
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006492
# Leído step 194 ← eta_matrix_000006492
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006520
# Leído step 195 ← eta_matrix_000006520
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006547
# Leído step 196 ← eta_matrix_000006547
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006576
# Leído step 197 ← eta_matrix_000006576
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006606
# Leído step 198 ← eta_matrix_000006606
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006637
# Leído step 199 ← eta_matrix_000006637
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006668
# Leído step 200 ← eta_matrix_000006668
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006700
# Leído step 201 ← eta_matrix_000006700
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006733
# Leído step 202 ← eta_matrix_000006733
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006766
# Leído step 203 ← eta_matrix_000006766
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006798
# Leído step 204 ← eta_matrix_000006798
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006829
# Leído step 205 ← eta_matrix_000006829
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006858
# Leído step 206 ← eta_matrix_000006858
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006887
# Leído step 207 ← eta_matrix_000006887
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006915
# Leído step 208 ← eta_matrix_000006915
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006942
# Leído step 209 ← eta_matrix_000006942
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006969
# Leído step 210 ← eta_matrix_000006969
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000006995
# Leído step 211 ← eta_matrix_000006995
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007022
# Leído step 212 ← eta_matrix_000007022
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007050
# Leído step 213 ← eta_matrix_000007050
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007080
# Leído step 214 ← eta_matrix_000007080
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007111
# Leído step 215 ← eta_matrix_000007111
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007142
# Leído step 216 ← eta_matrix_000007142
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007172
# Leído step 217 ← eta_matrix_000007172
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007204
# Leído step 218 ← eta_matrix_000007204
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007236
# Leído step 219 ← eta_matrix_000007236
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007268
# Leído step 220 ← eta_matrix_000007268
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007300
# Leído step 221 ← eta_matrix_000007300
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007332
# Leído step 222 ← eta_matrix_000007332
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007364
# Leído step 223 ← eta_matrix_000007364
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007396
# Leído step 224 ← eta_matrix_000007396
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007428
# Leído step 225 ← eta_matrix_000007428
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007460
# Leído step 226 ← eta_matrix_000007460
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007493
# Leído step 227 ← eta_matrix_000007493
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007527
# Leído step 228 ← eta_matrix_000007527
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007561
# Leído step 229 ← eta_matrix_000007561
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007595
# Leído step 230 ← eta_matrix_000007595
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007628
# Leído step 231 ← eta_matrix_000007628
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007660
# Leído step 232 ← eta_matrix_000007660
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007693
# Leído step 233 ← eta_matrix_000007693
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007726
# Leído step 234 ← eta_matrix_000007726
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007758
# Leído step 235 ← eta_matrix_000007758
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007789
# Leído step 236 ← eta_matrix_000007789
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007819
# Leído step 237 ← eta_matrix_000007819
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007849
# Leído step 238 ← eta_matrix_000007849
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007879
# Leído step 239 ← eta_matrix_000007879
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007910
# Leído step 240 ← eta_matrix_000007910
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007943
# Leído step 241 ← eta_matrix_000007943
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000007977
# Leído step 242 ← eta_matrix_000007977
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008012
# Leído step 243 ← eta_matrix_000008012
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008048
# Leído step 244 ← eta_matrix_000008048
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008083
# Leído step 245 ← eta_matrix_000008083
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008116
# Leído step 246 ← eta_matrix_000008116
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008147
# Leído step 247 ← eta_matrix_000008147
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008179
# Leído step 248 ← eta_matrix_000008179
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008212
# Leído step 249 ← eta_matrix_000008212
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008245
# Leído step 250 ← eta_matrix_000008245
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008278
# Leído step 251 ← eta_matrix_000008278
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008311
# Leído step 252 ← eta_matrix_000008311
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008343
# Leído step 253 ← eta_matrix_000008343
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008377
# Leído step 254 ← eta_matrix_000008377
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008413
# Leído step 255 ← eta_matrix_000008413
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008449
# Leído step 256 ← eta_matrix_000008449
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008485
# Leído step 257 ← eta_matrix_000008485
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008521
# Leído step 258 ← eta_matrix_000008521
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008557
# Leído step 259 ← eta_matrix_000008557
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008590
# Leído step 260 ← eta_matrix_000008590
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008623
# Leído step 261 ← eta_matrix_000008623
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008657
# Leído step 262 ← eta_matrix_000008657
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008692
# Leído step 263 ← eta_matrix_000008692
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008727
# Leído step 264 ← eta_matrix_000008727
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008761
# Leído step 265 ← eta_matrix_000008761
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008793
# Leído step 266 ← eta_matrix_000008793
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008824
# Leído step 267 ← eta_matrix_000008824
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008855
# Leído step 268 ← eta_matrix_000008855
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008886
# Leído step 269 ← eta_matrix_000008886
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008916
# Leído step 270 ← eta_matrix_000008916
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008947
# Leído step 271 ← eta_matrix_000008947
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000008977
# Leído step 272 ← eta_matrix_000008977
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009007
# Leído step 273 ← eta_matrix_000009007
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009038
# Leído step 274 ← eta_matrix_000009038
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009069
# Leído step 275 ← eta_matrix_000009069
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009099
# Leído step 276 ← eta_matrix_000009099
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009127
# Leído step 277 ← eta_matrix_000009127
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009157
# Leído step 278 ← eta_matrix_000009157
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009187
# Leído step 279 ← eta_matrix_000009187
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009217
# Leído step 280 ← eta_matrix_000009217
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009247
# Leído step 281 ← eta_matrix_000009247
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009276
# Leído step 282 ← eta_matrix_000009276
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009305
# Leído step 283 ← eta_matrix_000009305
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009334
# Leído step 284 ← eta_matrix_000009334
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009364
# Leído step 285 ← eta_matrix_000009364
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009397
# Leído step 286 ← eta_matrix_000009397
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009432
# Leído step 287 ← eta_matrix_000009432
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009468
# Leído step 288 ← eta_matrix_000009468
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009504
# Leído step 289 ← eta_matrix_000009504
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009540
# Leído step 290 ← eta_matrix_000009540
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009576
# Leído step 291 ← eta_matrix_000009576
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009612
# Leído step 292 ← eta_matrix_000009612
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009648
# Leído step 293 ← eta_matrix_000009648
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009683
# Leído step 294 ← eta_matrix_000009683
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009717
# Leído step 295 ← eta_matrix_000009717
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009751
# Leído step 296 ← eta_matrix_000009751
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009785
# Leído step 297 ← eta_matrix_000009785
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009819
# Leído step 298 ← eta_matrix_000009819
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009853
# Leído step 299 ← eta_matrix_000009853
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009886
# Leído step 300 ← eta_matrix_000009886
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009918
# Leído step 301 ← eta_matrix_000009918
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009950
# Leído step 302 ← eta_matrix_000009950
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000009984
# Leído step 303 ← eta_matrix_000009984
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010020
# Leído step 304 ← eta_matrix_000010020
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010056
# Leído step 305 ← eta_matrix_000010056
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010091
# Leído step 306 ← eta_matrix_000010091
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010126
# Leído step 307 ← eta_matrix_000010126
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010160
# Leído step 308 ← eta_matrix_000010160
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010196
# Leído step 309 ← eta_matrix_000010196
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010233
# Leído step 310 ← eta_matrix_000010233
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010269
# Leído step 311 ← eta_matrix_000010269
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010305
# Leído step 312 ← eta_matrix_000010305
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010339
# Leído step 313 ← eta_matrix_000010339
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010372
# Leído step 314 ← eta_matrix_000010372
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010403
# Leído step 315 ← eta_matrix_000010403
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010432
# Leído step 316 ← eta_matrix_000010432
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010459
# Leído step 317 ← eta_matrix_000010459
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010487
# Leído step 318 ← eta_matrix_000010487
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010516
# Leído step 319 ← eta_matrix_000010516
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010544
# Leído step 320 ← eta_matrix_000010544
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010571
# Leído step 321 ← eta_matrix_000010571
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010598
# Leído step 322 ← eta_matrix_000010598
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010625
# Leído step 323 ← eta_matrix_000010625
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010652
# Leído step 324 ← eta_matrix_000010652
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010680
# Leído step 325 ← eta_matrix_000010680
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010709
# Leído step 326 ← eta_matrix_000010709
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010741
# Leído step 327 ← eta_matrix_000010741
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010773
# Leído step 328 ← eta_matrix_000010773
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010806
# Leído step 329 ← eta_matrix_000010806
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010842
# Leído step 330 ← eta_matrix_000010842
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010878
# Leído step 331 ← eta_matrix_000010878
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010913
# Leído step 332 ← eta_matrix_000010913
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010947
# Leído step 333 ← eta_matrix_000010947
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000010982
# Leído step 334 ← eta_matrix_000010982
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011018
# Leído step 335 ← eta_matrix_000011018
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011053
# Leído step 336 ← eta_matrix_000011053
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011087
# Leído step 337 ← eta_matrix_000011087
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011121
# Leído step 338 ← eta_matrix_000011121
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011155
# Leído step 339 ← eta_matrix_000011155
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011189
# Leído step 340 ← eta_matrix_000011189
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011222
# Leído step 341 ← eta_matrix_000011222
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011254
# Leído step 342 ← eta_matrix_000011254
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011287
# Leído step 343 ← eta_matrix_000011287
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011320
# Leído step 344 ← eta_matrix_000011320
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011352
# Leído step 345 ← eta_matrix_000011352
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011384
# Leído step 346 ← eta_matrix_000011384
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011417
# Leído step 347 ← eta_matrix_000011417
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011450
# Leído step 348 ← eta_matrix_000011450
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011483
# Leído step 349 ← eta_matrix_000011483
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011516
# Leído step 350 ← eta_matrix_000011516
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011549
# Leído step 351 ← eta_matrix_000011549
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011582
# Leído step 352 ← eta_matrix_000011582
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011614
# Leído step 353 ← eta_matrix_000011614
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011645
# Leído step 354 ← eta_matrix_000011645
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011674
# Leído step 355 ← eta_matrix_000011674
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011703
# Leído step 356 ← eta_matrix_000011703
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011731
# Leído step 357 ← eta_matrix_000011731
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011760
# Leído step 358 ← eta_matrix_000011760
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011791
# Leído step 359 ← eta_matrix_000011791
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011823
# Leído step 360 ← eta_matrix_000011823
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011856
# Leído step 361 ← eta_matrix_000011856
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011889
# Leído step 362 ← eta_matrix_000011889
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011922
# Leído step 363 ← eta_matrix_000011922
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011955
# Leído step 364 ← eta_matrix_000011955
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000011990
# Leído step 365 ← eta_matrix_000011990
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012025
# Leído step 366 ← eta_matrix_000012025
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012060
# Leído step 367 ← eta_matrix_000012060
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012094
# Leído step 368 ← eta_matrix_000012094
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012128
# Leído step 369 ← eta_matrix_000012128
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012163
# Leído step 370 ← eta_matrix_000012163
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012198
# Leído step 371 ← eta_matrix_000012198
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012234
# Leído step 372 ← eta_matrix_000012234
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012270
# Leído step 373 ← eta_matrix_000012270
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012306
# Leído step 374 ← eta_matrix_000012306
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012342
# Leído step 375 ← eta_matrix_000012342
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012376
# Leído step 376 ← eta_matrix_000012376
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000012408
# ...
# Leído step 1403 ← eta_matrix_000043665
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043687
# Leído step 1404 ← eta_matrix_000043687
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043709
# Leído step 1405 ← eta_matrix_000043709
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043731
# Leído step 1406 ← eta_matrix_000043731
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043752
# Leído step 1407 ← eta_matrix_000043752
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043772
# Leído step 1408 ← eta_matrix_000043772
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043792
# Leído step 1409 ← eta_matrix_000043792
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043812
# Leído step 1410 ← eta_matrix_000043812
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043833
# Leído step 1411 ← eta_matrix_000043833
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043856
# Leído step 1412 ← eta_matrix_000043856
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043881
# Leído step 1413 ← eta_matrix_000043881
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043908
# Leído step 1414 ← eta_matrix_000043908
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043935
# Leído step 1415 ← eta_matrix_000043935
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043962
# Leído step 1416 ← eta_matrix_000043962
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000043989
# Leído step 1417 ← eta_matrix_000043989
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044018
# Leído step 1418 ← eta_matrix_000044018
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044050
# Leído step 1419 ← eta_matrix_000044050
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044086
# Leído step 1420 ← eta_matrix_000044086
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044125
# Leído step 1421 ← eta_matrix_000044125
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044165
# Leído step 1422 ← eta_matrix_000044165
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044205
# Leído step 1423 ← eta_matrix_000044205
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044245
# Leído step 1424 ← eta_matrix_000044245
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044285
# Leído step 1425 ← eta_matrix_000044285
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044325
# Leído step 1426 ← eta_matrix_000044325
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044365
# Leído step 1427 ← eta_matrix_000044365
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044401
# Leído step 1428 ← eta_matrix_000044401
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044434
# Leído step 1429 ← eta_matrix_000044434
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044466
# Leído step 1430 ← eta_matrix_000044466
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044497
# Leído step 1431 ← eta_matrix_000044497
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044526
# Leído step 1432 ← eta_matrix_000044526
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044554
# Leído step 1433 ← eta_matrix_000044554
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044582
# Leído step 1434 ← eta_matrix_000044582
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044610
# Leído step 1435 ← eta_matrix_000044610
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044642
# Leído step 1436 ← eta_matrix_000044642
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044676
# Leído step 1437 ← eta_matrix_000044676
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044709
# Leído step 1438 ← eta_matrix_000044709
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044743
# Leído step 1439 ← eta_matrix_000044743
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044778
# Leído step 1440 ← eta_matrix_000044778
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044814
# Leído step 1441 ← eta_matrix_000044814
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044850
# Leído step 1442 ← eta_matrix_000044850
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044886
# Leído step 1443 ← eta_matrix_000044886
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044921
# Leído step 1444 ← eta_matrix_000044921
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044955
# Leído step 1445 ← eta_matrix_000044955
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000044989
# Leído step 1446 ← eta_matrix_000044989
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045022
# Leído step 1447 ← eta_matrix_000045022
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045054
# Leído step 1448 ← eta_matrix_000045054
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045085
# Leído step 1449 ← eta_matrix_000045085
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045114
# Leído step 1450 ← eta_matrix_000045114
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045141
# Leído step 1451 ← eta_matrix_000045141
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045167
# Leído step 1452 ← eta_matrix_000045167
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045191
# Leído step 1453 ← eta_matrix_000045191
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045214
# Leído step 1454 ← eta_matrix_000045214
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045237
# Leído step 1455 ← eta_matrix_000045237
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045260
# Leído step 1456 ← eta_matrix_000045260
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045285
# Leído step 1457 ← eta_matrix_000045285
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045310
# Leído step 1458 ← eta_matrix_000045310
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045334
# Leído step 1459 ← eta_matrix_000045334
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045359
# Leído step 1460 ← eta_matrix_000045359
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045386
# Leído step 1461 ← eta_matrix_000045386
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045416
# Leído step 1462 ← eta_matrix_000045416
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045448
# Leído step 1463 ← eta_matrix_000045448
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045480
# Leído step 1464 ← eta_matrix_000045480
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045512
# Leído step 1465 ← eta_matrix_000045512
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045543
# Leído step 1466 ← eta_matrix_000045543
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045573
# Leído step 1467 ← eta_matrix_000045573
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045602
# Leído step 1468 ← eta_matrix_000045602
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045631
# Leído step 1469 ← eta_matrix_000045631
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045662
# Leído step 1470 ← eta_matrix_000045662
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045693
# Leído step 1471 ← eta_matrix_000045693
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045725
# Leído step 1472 ← eta_matrix_000045725
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045757
# Leído step 1473 ← eta_matrix_000045757
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045788
# Leído step 1474 ← eta_matrix_000045788
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045817
# Leído step 1475 ← eta_matrix_000045817
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045847
# Leído step 1476 ← eta_matrix_000045847
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045879
# Leído step 1477 ← eta_matrix_000045879
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045914
# Leído step 1478 ← eta_matrix_000045914
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045953
# Leído step 1479 ← eta_matrix_000045953
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000045993
# Leído step 1480 ← eta_matrix_000045993
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046034
# Leído step 1481 ← eta_matrix_000046034
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046075
# Leído step 1482 ← eta_matrix_000046075
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046115
# Leído step 1483 ← eta_matrix_000046115
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046155
# Leído step 1484 ← eta_matrix_000046155
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046195
# Leído step 1485 ← eta_matrix_000046195
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046233
# Leído step 1486 ← eta_matrix_000046233
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046270
# Leído step 1487 ← eta_matrix_000046270
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046306
# Leído step 1488 ← eta_matrix_000046306
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046341
# Leído step 1489 ← eta_matrix_000046341
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046375
# Leído step 1490 ← eta_matrix_000046375
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046408
# Leído step 1491 ← eta_matrix_000046408
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046439
# Leído step 1492 ← eta_matrix_000046439
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046469
# Leído step 1493 ← eta_matrix_000046469
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046496
# Leído step 1494 ← eta_matrix_000046496
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046521
# Leído step 1495 ← eta_matrix_000046521
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046544
# Leído step 1496 ← eta_matrix_000046544
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046565
# Leído step 1497 ← eta_matrix_000046565
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046585
# Leído step 1498 ← eta_matrix_000046585
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046604
# Leído step 1499 ← eta_matrix_000046604
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046624
# Leído step 1500 ← eta_matrix_000046624
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046646
# Leído step 1501 ← eta_matrix_000046646
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046669
# Leído step 1502 ← eta_matrix_000046669
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046692
# Leído step 1503 ← eta_matrix_000046692
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046714
# Leído step 1504 ← eta_matrix_000046714
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046735
# Leído step 1505 ← eta_matrix_000046735
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046755
# Leído step 1506 ← eta_matrix_000046755
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046776
# Leído step 1507 ← eta_matrix_000046776
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046797
# Leído step 1508 ← eta_matrix_000046797
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046819
# Leído step 1509 ← eta_matrix_000046819
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046842
# Leído step 1510 ← eta_matrix_000046842
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046868
# Leído step 1511 ← eta_matrix_000046868
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046897
# Leído step 1512 ← eta_matrix_000046897
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046928
# Leído step 1513 ← eta_matrix_000046928
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046961
# Leído step 1514 ← eta_matrix_000046961
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000046996
# Leído step 1515 ← eta_matrix_000046996
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000047033
# Leído step 1516 ← eta_matrix_000047033
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000047071
# Leído step 1517 ← eta_matrix_000047071
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000047111
# Leído step 1518 ← eta_matrix_000047111
# /projects/DEIKE/cmartinb/Ruidata/surface_kpHs0p3_dt0p2_kp0p157_g9p8/eta_matrix_000047153
# Leído step 1519 ← eta_matrix_000047153
# '\n\nfor i in istep_c:\n    filename = work_dir + f\'eta/eta_loc/eta_loc_t{int(i):09}.bin\'\n    etalo = np.fromfile(filename)\n    size  = etalo.shape;\n    tot_row = 18\n    tot_row_i = int(size[0]/tot_row);\n    etalo = etalo.reshape([tot_row_i, tot_row]);\n    \n    eta_m0  = 1.0; cirp_th = 0.20;\n    new_row = 0;\n    for i in range(tot_row_i):\n        if ( abs(etalo[i][12]-eta_m0) < cirp_th ):\n            new_row += 1;\n    #\n    print(\'iteration\', j ,"Second pass of remove")\n    etal = np.zeros([new_row, 18]);\n    for i in range(new_row):\n        if ( abs(etalo[i][12]-eta_m0) < cirp_th ):\n            etal[i][:] = etalo[i][:];\n    xarray = np.linspace(-L0/2., L0/2.,N,endpoint=False)+L0/2/N/2 # Centered grid for interpolation\n    yarray = np.linspace(-L0/2., L0/2.,N,endpoint=False)+L0/2/N/2 # Centered grid for interpolation\n    xtile, ytile = np.meshgrid(xarray,yarray)\n    #print(etal[:,0])\n    eta = griddata((etal[:,0].ravel(), etal[:,1].ravel()), etal[:,12].ravel(), (xtile, ytile), method=\'nearest\')\n    eta_series[j]= eta\n    j+=1\n\n'

# %%
#np.save(f'/projects/DEIKE/cmartinb/eta/rui_eta_series_re{reA}_bo0{Bo}_P{kpHs}_uoc{uoc}_reW{reW}_L{maxLevel}.npy', eta_series)
import h5py

with h5py.File(f'/projects/DEIKE/cmartinb/eta/rui_eta_series_kpHs0p3_dt0p2_kp0p157_g9p8.h5','w') as f:
    f.create_dataset('eta', data=eta_series, compression='gzip')

# %%
print(f'/projects/DEIKE/cmartinb/eta/rui_eta_series_kpHs0p3_dt0p2_kp0p157_g9p8.h5')
# Out:
# /projects/DEIKE/cmartinb/eta/rui_eta_series_re720_bo01000_P0p16_uoc0p50_reW2.5e4_L10.h5
